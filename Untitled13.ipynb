# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52059/23CSBTB39-40/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 5

# %% [markdown]
# Question:1

# %%
import pandas as pd
file_path='Salary_Data.csv'
data=pd.read_csv(file_path)
print(data.head())
X=data.iloc[:,:-1]
y=data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",y.head())
import matplotlib.pyplot as plt
for column in X.columns:
    plt.figure(figsize=(8,6))
    plt.scatter(X[column],y,alpha=0.5)
    plt.title(f'{column}vs Target')
    plt.xlabel(column)
    plt.ylabel("Target")
    plt.show()
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_normalized=scaler.fit_transform(X)
    y_normmalized=scaler.fit_transform(y.values.reshape(-1,1))
    X_normalized=pd.DataFrame(X_normalized,columns=X.columns)
    print("Normalized Features:\n",X_normalized.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# Features:
#     YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# Target:
#  0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64
# Normalized Features:
#     YearsExperience
# 0         0.000000
# 1         0.021277
# 2         0.042553
# 3         0.095745
# 4         0.117021

# %% [markdown]
# Question:2

# %%
import pandas as pd
file_path='diabetes_data_upload.csv'
data=pd.read_csv(file_path)
print(data.head())
X=data.iloc[:,:-1]
y=data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",y.head())
import matplotlib.pyplot as plt
for column in X.columns:
    plt.figure(figsize=(8,6))
    plt.scatter(X[column],y,alpha=0.5)
    plt.title(f'{column}vs Target')
    plt.xlabel(column)
    plt.ylabel("Target")
    plt.show()
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    numerical_cols = X.select_dtypes(include=['number']).columns
    X_normalized = X.copy()
    X_normalized[numerical_cols] = scaler.fit_transform(X_normalized[numerical_cols])

    if y.dtype == 'object':
        from sklearn.preprocessing import LabelEncoder
        le = LabelEncoder()
        y_normalized = le.fit_transform(y)
    else:
        y_normalized = scaler.fit_transform(y.values.reshape(-1,1))

    X_normalized=pd.DataFrame(X_normalized,columns=X.columns)
    print("Normalized Features:\n",X_normalized.head())
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...
